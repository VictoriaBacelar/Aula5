# %%
from random import randint

def noterror(num,exp):

  if(exp<0):
    num=str(num)
    resp = ('0' *(exp*-1))
    resp = '0.'+ resp + str(num) + '0'
    resp = float(resp)
    return resp
  else:
    num= '0.' + str(num) + '0'
    num=float(num)*10**exp
    return num

def media(num):
  while(cont<100):
    resp += num[cont]
  resp/100
  return resp

def desvio(num):
  while(cont<100):
    resp += num[cont]
  resp/100
  return resp

def trunc(resp):
  resp = str(resp)
  fim = ''
  cont=0
  cont2=0
  cont3=0
  trunc = ''
  trunc2 = ''
  resp1 = resp.split('.')[1]
  part1 = resp.split('.')[0]


  if(part1 == '0' and resp1[0] == '0'):
    while(cont < len(resp1)):
      if(resp1[cont] == '0'):
        cont2 = cont
        if(resp1[cont2+1] != '0'):
          resp1 = resp1[cont2+1:len(resp1)]
          break
        cont+=1
    trunc = part1 +'.'+ resp1
  else:
    if(resp[0]=='0'):
      while(cont!=5):
        trunc += resp[cont]
        cont+=1
    else:
      while(cont < len(resp)):
        if(resp[cont]=='.'):
          break
        fim += resp[cont]
        cont +=1
      trunc = "0." + fim + resp1
      cont=0
      print(resp)
      while(cont!=5):
        trunc2 += trunc[cont]
        cont+=1
      trunc=trunc2
  return trunc

def arredon(resp):
  resp = str(resp)
  cont=0
  cont3=0
  cont2=2
  arred = ''

  resp1 = resp.split('.')[1]
  part1 = resp.split('.')[0]


  if(part1 == '0' and resp1[0] == '0'):
    while(cont < len(resp1)):
      if(resp1[cont] == '0'):
        cont2 = cont
        if(resp1[cont2+1] != '0'):
          resp1 = resp1[cont2+1:len(resp1)]
          break
        cont+=1
    resp = part1 +'.'+ resp1

  if(resp[0]!='0'):
    if(float(resp) > 0.999 and float(resp)<99.999):
      while(cont < 3):
        arred += resp[cont]
        cont+=1
      if(int(resp[4])>=5):
        arred = str(float(arred)+1)

    if(float(resp) > 99.999):
      while(cont < 3):
        arred += resp[cont]
        cont+=1
      if(int(resp[4])>=5):
        arred = str(float(arred)+1)      
  else:

    if(int(resp[5]) <= 5):
      while(cont!=5):
        arred += resp[cont]
        cont+=1
    else:
      while(cont2!=5):
        arred += resp[cont2]
        cont2+=1
      arred = str(int(arred)+1)
      arred = "0."+ arred
  return arred


def soma(num,num1):
  resp = num+num1
  resp = str(resp)
  cont = 0
  while(cont < len(resp)):
    if(resp[cont]=='.'):
      break
    cont +=1
  resp = float(resp)
  return resp



print("antes:")
print("--------------------------------")

cont=0
arr = []
arr2 = []
"""
while(cont < 100):
  num = (randint(0,999))
  num1 = (randint(0,999))
  num2 = (randint(0,999))
  num3 = (randint(0,999))
  exp = (randint(-3,3))
  exp1 = (randint(-3,3))
  exp2 = (randint(-3,3))
  exp3 = (randint(-3,3))

  num = noterror(num,exp)
  num1 = noterror(num1,exp1)
  num2 = noterror(num2,exp2)
  num3 = noterror(num3,exp3)

  final = soma(num,num1)
  erro_soma = float(final) - float(trunc(final))
  end = erro_soma*num2
  erro_mult = end - float(trunc(end))
  if(float(erro_mult)<0 ):
    erro_mult = float(erro_mult)*-1
  dim = erro_mult-num3
  erro_final = dim - float(trunc(dim))

  final2 = soma(num,num1)
  erro_soma2 = float(final2) - float(arredon(final2))
  end2 = erro_soma2*num2
  erro_mult2 = end2 - float(arredon(end2))
  if(float(erro_mult2)<0 ):
    erro_mult2 = float(erro_mult2)*-1
  dim2 = erro_mult2-num3
  erro_final2 = dim2 - float(arredon(dim2))


  arr.append(erro_final)
  arr2.append(erro_final2)
  cont+=1
"""


num = (randint(0,999))
num1 = (randint(0,999))
num2 = (randint(0,999))
num3 = (randint(0,999))
exp = (randint(-3,3))
exp = (randint(-3,3))
exp1 = (randint(-3,3))
exp2 = (randint(-3,3))
exp3 = (randint(-3,3))

print("x",num)
print("y",num1)
print("z",num2)
print("t",num3)

print("exp",exp)
print("exp",exp1)
print("exp",exp2)
print("exp",exp3)
print("--------------------------------")
print("depois:")
num = noterror(num,exp)
num1 = noterror(num1,exp1)
num2 = noterror(num2,exp2)
num3 = noterror(num3,exp3)

print("--------------------------------")
print(num)
print(num1)
print(num2)
print(num3)


print("---------------Truncamento-------------------")

'''
n = noterror(418,-1)
n1 = noterror(399,0)
num2 = noterror(250,-3)
num3 = noterror(577,2)
print(n)
print(n1)
print(num2)
print(num3)
'''

final = soma(num,num1)
print("soma",final)
erro_soma = (float(final) - float(trunc(final)))/float(trunc(final))
if(float(erro_soma)<0 ):
  erro_soma = float(erro_soma)*-1

end = erro_soma*num2

erro_mult = (end - float(trunc(end))/float(trunc(end)))/float(trunc(end))

if(float(erro_mult)<0 ):
  erro_mult = float(erro_mult)*-1

dim = float(trunc(end))-num3
if(float(dim)<0 ):
  dim = float(dim)*-1
erro_final = ((dim - float(trunc(dim)))/float(trunc(dim)))/float(trunc(dim))

print("trunc soma",trunc(final))
print("erro_soma",erro_soma)
print("erro final",dim)
print("multipli",end)
print("trun mult",trunc(end))
print("trunc multp",trunc(end))
print("erro_mult",erro_mult)
print("erro_mult",erro_mult)

print("-------------arredondamento-------------------")


final = soma(num,num1)
erro_soma = (float(final) - float(arredon(final)))/float(arredon(final))
if(float(erro_soma)<0 ):
  erro_soma = float(erro_soma)*-1
end = erro_soma*num2
erro_mult = (end - float(arredon(end))/float(arredon(end)))/float(arredon(end))
if(float(erro_mult)<0 ):
  erro_mult = float(erro_mult)*-1
dim = float(arredon(end))-num3
if(float(dim)<0 ):
  dim = float(dim)*-1
erro_final = ((dim - float(arredon(dim)))/float(arredon(dim)))/float(arredon(dim))

print("arred soma",trunc(final))
print("erro_soma",erro_soma)
print("erro final",dim)
print("multipli",end)
print("arred mult",trunc(end))
print("arred multp",trunc(end))
print("erro_mult",erro_mult)
print("erro_mult",erro_mult)
# Out:
# antes:
# --------------------------------
# x 257
# y 208
# z 592
# t 120
# exp -1
# exp -2
# exp -1
# exp -3
# --------------------------------
# depois:
# --------------------------------
# 0.0257
# 0.00208
# 0.0592
# 0.00012
# ---------------Truncamento-------------------
# soma 0.02778
# trunc soma 0.2778
# erro_soma 0.9000000000000001
# erro final 0.53268
# multipli 0.05328000000000001
# trun mult 0.5328000000000001
# trunc multp 0.5328000000000001
# erro_mult 1.7768768768768768
# erro_mult 1.7768768768768768
# -------------arredondamento-------------------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-0117b6988320> in <module>()
#     254
#     255 final = soma(num,num1)
# --> 256 erro_soma = (float(final) - float(arredon(final)))/float(arredon(final))
#     257 if(float(erro_soma)<0 ):
#     258   erro_soma = float(erro_soma)*-1
#
# ...
